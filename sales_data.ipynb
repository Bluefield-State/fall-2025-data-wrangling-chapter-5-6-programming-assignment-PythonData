# %%
#
# ~~~~~~~~~~~~~~~~~~IMPORTANT~~~~~~~~~~~~~~~~~~
#
# run this code first to download instructions and support files. 
# You will not be able to complete the assignment without them.
# Instructions will be found in the README.md file in the support_files folder.

import os

if not os.path.exists("support_files"):
    # !git clone --depth 1 --filter=blob:none --sparse \
        https://github.com/Bluefield-State/fall-2025-data-wrangling-chapter-5-6-programming-assignment-PythonData.git repo

    # !cd repo && git sparse-checkout set support_files
    # !mv repo/support_files .
    # !rm -rf repo

# %%
import pandas as pd

# Step 1: Read sales data from the CSV file
file_path = 'sales_data.csv'

def read_sales_data(file_path):

# Check if the data was loaded successfully

    # Step 2: Calculate total sales for each product


    # Step 3: Calculate average sale price for each product
    

    # Step 4: Identify the product with the highest total sales


    # Step 5: Calculate correlation and covariance


    # Step 6: Create a summary report


    # Step 7: Write the summary report to a new CSV file
